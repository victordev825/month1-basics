# %% [markdown]
# <a href="https://colab.research.google.com/github/victordev825/month1-basics/blob/main/month1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello im building my career")
# Out:
# hello im building my career

# %%
student_name="amaka john"
course="programming"
grade="distinction"
print(student_name)
print(course)
print(grade)
# Out:
# amaka john
# programming
# distinction

# %%
score=97
print(score)
print(type(score))
# Out:
# 97
# <class 'int'>

# %%
score=87
if score>=100:
  print("pass-issue certificate")
else:
  print("fail-no certificate")
# Out:
# fail-no certificate

# %%
students=["alfred","james","rose mary"]
for student in students:
  print(student)
# Out:
# alfred
# james
# rose mary

# %%
for student in students:
  print("certificate ready for",student)
# Out:
# certificate ready for alfred
# certificate ready for james
# certificate ready for rose mary

# %%
student={"name":"amaka james","course":"web design","grade":"distinction"}
print(student)
print(student["name"])
# Out:
# {'name': 'amaka james', 'course': 'web design', 'grade': 'distinction'}
# amaka james

# %%
student["score"]=87
print(student)
# Out:
# {'name': 'amaka james', 'course': 'web design', 'grade': 'distinction', 'score': 87}

# %%
student["subject"]="english"
print(student)
# Out:
# {'name': 'amaka james', 'course': 'web design', 'grade': 'distinction', 'score': 87, 'subject': 'english'}

# %%
for key in student:
  print(key,"-",student[key])
# Out:
# name - amaka james
# course - web design
# grade - distinction
# score - 87
# subject - english

# %%
def issue_certificate(name, grade):
    print("Certificate for", name, "- Grade:", grade)

issue_certificate("Amaka Obi", "Distinction")
issue_certificate("Tunde", "Pass")
# Out:
# Certificate for Amaka Obi - Grade: Distinction
# Certificate for Tunde - Grade: Pass

# %%
import json
student={
    "name":"amaka james",
    "course":"web design",
    "grade":"distinction"
}
json_data=json.dumps(student)
print(json_data)
# Out:
# {"name": "amaka james", "course": "web design", "grade": "distinction"}

# %%
import requests
response=requests.post("https://httpbin.org/post",json=student)
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'args': {}, 'data': '{"name": "amaka james", "course": "web design", "grade": "distinction"}', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '71', 'Content-Type': 'application/json', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.4', 'X-Amzn-Trace-Id': 'Root=1-6aac48e0-4dece88e43a8ba1e18eb34de'}, 'json': {'course': 'web design', 'grade': 'distinction', 'name': 'amaka james'}, 'origin': '34.125.102.184', 'url': 'https://httpbin.org/post'}
